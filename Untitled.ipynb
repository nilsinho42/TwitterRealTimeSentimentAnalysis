# %%
# Packages that you may need to install...
# !pip install requests_oauthlib
# !pip install twython
# !pip install nltk
# !pip install kaggle
# Out:
# ...
# [sudo] password for devntp:

# %%
# Packages Used
from pyspark.streaming import StreamingContext
from pyspark import SparkContext
from requests_oauthlib import OAuth1Session
from operator import add
import requests_oauthlib
from time import gmtime, strftime
import requests
import time
import string
import ast
import json

# %%
# Natural Language Processing Packages
import nltk
from nltk.classify import NaiveBayesClassifier
from nltk.sentiment import SentimentAnalyzer
from nltk.corpus import subjectivity
from nltk.corpus import stopwords
from nltk.sentiment.util import *

# %%
batchIntervalInSeconds = 5

# %%
# Creating StreamingContext
sparkStreamingContext = StreamingContext(sc, batchIntervalInSeconds)

# %% [markdown]
# Michigan University Kaggle's database: https://inclass.kaggle.com/c/si650winter11

# %%
# Downloading dataset to train classifier (you should have Kaggle API Credentials and should accept the rules of competition in kaggle website)
# !kaggle competitions download -c si650winter11
# !unzip si650winter11.zip
# Out:
# si650winter11.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  si650winter11.zip
# replace testdata.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
# Loading Data
trainingData = sc.textFile("training.txt")

# %%
dataHeader = trainingData.take(1)[0]
trainingData = trainingData.filter(lambda line: line != dataHeader)

# %%
type(trainingData)
# Out:
# pyspark.rdd.PipelinedRDD

# %%
spark = SparkSession.builder.appName('trainingData').getOrCreate()
columns = ["analyse","sentence"]
df = spark.createDataFrame(data = trainingData, schema = columns)
df.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-f5ca808b23fc> in <module>
#       1 spark = SparkSession.builder.appName('trainingData').getOrCreate()
#       2 columns = ["analyse","sentence"]
# ----> 3 df = spark.createDataFrame(data = trainingData, schema = columns)
#       4 df.show()
#
# /opt/spark/python/pyspark/sql/session.py in createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     673             return super(SparkSession, self).createDataFrame(
#     674                 data, schema, samplingRatio, verifySchema)
# --> 675         return self._create_dataframe(data, schema, samplingRatio, verifySchema)
#     676
#     677     def _create_dataframe(self, data, schema, samplingRatio, verifySchema):
#
# /opt/spark/python/pyspark/sql/session.py in _create_dataframe(self, data, schema, samplingRatio, verifySchema)
#     696
# ...
